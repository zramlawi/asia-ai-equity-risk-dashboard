# %% [markdown]
# # Asia AI Equity Risk Dashboard — Exploratory Analysis
#
# Use this notebook to validate the watchlist, load approved market data, and inspect basic risk metrics. Do not treat the example watchlist as investment advice.

# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().parent))
from src.data import load_tickers, validate_watchlist

tickers = load_tickers()
tickers

# %%
validate_watchlist(tickers)

# %% [markdown]
# ## Next steps
#
# 1. Resolve duplicate or multi-listed exposure in the watchlist.
# 2. Load adjusted-close prices from an approved source.
# 3. Pass the wide price table to `src.risk.risk_snapshot`.
# 4. Record data lineage and material limitations in `docs/data-sources.md`.
